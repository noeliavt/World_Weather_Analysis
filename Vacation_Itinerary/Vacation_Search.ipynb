# %% [markdown]
# ## Deliverable 2. Create a Customer Travel Destinations Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps
import numpy as np

# Import API key
from config import g_key


# Import API key
from config import g_key


# Configure gmaps API key
gmaps.configure(api_key=g_key)

# %%
# 1. Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("Weather_Database/WeatherPy_database.csv")
city_data_df.head()
# Out:
#    City_ID        City Country      Lat       Lng  Max Temp  Humidity  \
# 0        0    Luderitz     NaN -26.6481   15.1594     58.41        92
# 1        1       Kapaa      US  22.0752 -159.3190     73.38        97
# 2        2        Sumy      UA  50.9216   34.8003     42.64        94
# 3        3  Lavrentiya      RU  65.5833 -171.0000     33.84        99
# 4        4     Madaoua      NE  14.0730    5.9600     81.39        13
#
#    Cloudiness  Wind Speed Current Description
# 0          56        9.73       broken clouds
# 1         100       16.11                mist
# 2          47        7.45    scattered clouds
# 3          89        4.97     overcast clouds
# 4           0        6.17           clear sky

# %%
# 2. Prompt the user to enter minimum and maximum temperature criteria 
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/zq/rwx6mtq50yd_vfcnh_qt_z580000gn/T/ipykernel_8992/1434671282.py in <module>
#       1 # 2. Prompt the user to enter minimum and maximum temperature criteria
# ----> 2 min_temp = float(input("What is the minimum temperature you would like for your trip? "))
#       3 max_temp = float(input("What is the maximum temperature you would like for your trip? "))
#
# ValueError: could not convert string to float:

# %%
# 3. Filter the city_data_df DataFrame using the input statements to create a new DataFrame using the loc method.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head(10)
# Out:
#     City_ID            City Country      Lat       Lng  Max Temp  Humidity  \
# 4         4         Madaoua      NE  14.0730    5.9600     81.39        13
# 7         7         Rikitea      PF -23.1203 -134.9692     76.44        79
# 9         9       Matamoros      MX  25.5333 -103.2500     87.55        13
# 11       11  Cabo San Lucas      MX  22.8909 -109.9124     76.60        75
# 14       14           Vaini      TO -21.2000 -175.2000     80.76        74
# 18       18           Arlit      NE  18.7369    7.3853     83.44        16
# 26       26       Kavaratti      IN  10.5669   72.6420     83.57        78
# 27       27         Zhenlai      CN  45.8495  123.2973     77.70        27
# 30       30      Bridgetown      BB  13.1000  -59.6167     81.09        83
# 31       31        Victoria      HK  22.2855  114.1577     80.96        56
#
#     Cloudiness  Wind Speed Current Description
# 4            0        6.17           clear sky
# 7          100       12.41          light rain
# 9           65        4.76       broken clouds
# 11         100        8.99     overcast clouds
# 14          75        8.05       broken clouds
# 18           0        7.61           clear sky
# 26         100       16.08       moderate rain
# 27          31       12.39    scattered clouds
# 30          40       14.97    scattered clouds
# 31          99        5.99     overcast clouds

# %%
# 4a. Determine if there are any empty rows.
preferred_cities_df.count()
# Out:
# City_ID                220
# City                   220
# Country                220
# Lat                    220
# Lng                    220
# Max Temp               220
# Humidity               220
# Cloudiness             220
# Wind Speed             220
# Current Description    220
# dtype: int64

# %%
# 4b. Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
preferred_cities_df.isnull().sum()
preferred_cities_df.replace('', np.nan, inplace=True)
clean_df=preferred_cities_df.dropna()
# Out:
# /opt/anaconda3/envs/PhytonDataEnv/lib/python3.7/site-packages/pandas/core/frame.py:5244: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,

# %%
# 5a. Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = clean_df[["City", "Country", "Max Temp", "Current Description", "Lat", "Lng"]].copy()

# 5b. Create a new column "Hotel Name"
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#               City Country  Max Temp Current Description      Lat       Lng  \
# 4          Madaoua      NE     81.39           clear sky  14.0730    5.9600
# 7          Rikitea      PF     76.44          light rain -23.1203 -134.9692
# 9        Matamoros      MX     87.55       broken clouds  25.5333 -103.2500
# 11  Cabo San Lucas      MX     76.60     overcast clouds  22.8909 -109.9124
# 14           Vaini      TO     80.76       broken clouds -21.2000 -175.2000
# 18           Arlit      NE     83.44           clear sky  18.7369    7.3853
# 26       Kavaratti      IN     83.57       moderate rain  10.5669   72.6420
# 27         Zhenlai      CN     77.70    scattered clouds  45.8495  123.2973
# 30      Bridgetown      BB     81.09    scattered clouds  13.1000  -59.6167
# 31        Victoria      HK     80.96     overcast clouds  22.2855  114.1577
#
#    Hotel Name
# 4
# 7
# 9
# 11
# 14
# 18
# 26
# 27
# 30
# 31

# %%
# Set the parameters to search for a hotel in Paris.
params = {
    "radius": 5000,
    "types": "lodging",
    "key": g_key,
    "location": "48.8566, 2.3522"}
# Use base URL to search for hotels in Paris.
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
# Make request and get the JSON data from the search.
hotels = requests.get(base_url, params=params).json()

hotels
# Out:
# {'html_attributions': [],
#  'next_page_token': 'Aap_uEAGgzTDN3BQLiFo-2qPIKMSidmZxTzwHA11PcPxe77RdfblFYhVEVGt7INau-OqIycpr3HngAxBe5K4aiSDBhV5HW_FgbWVGbPG1lRLy0CHWk_hcE4tD6Sxl3LCVAQ7fZ0vsfbcgFPOFvI91h-yElRIPWbRWwUOX7barZ6dtbNRwFpn_Tgu4lQU_hvPCNVjLdaVSTKUYntn8vhTppa5W7cASHA887KPHUMReeVgZjYPAP6NhPdgXKxHdiPpz3gypCMbanyKpfPEg5rGBlF3VtjGI0GBc8ahYBY1fQotOpfh61c0cHo6IbTBxKu0vI7KkkWeZyMILB8lbUr02o2XsGa3YmO6HFQa84AkzG6FCtsQJpj_GUrit7nnd9LqfwZn-ZzUf8BvzctKtf6RI3xixCPdMHynPuj_PVt62Y65yYNGEA45i8yux-BV',
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8581126, 'lng': 2.3529277},
#     'viewport': {'northeast': {'lat': 48.8594360302915,
#       'lng': 2.354355480291502},
#      'southwest': {'lat': 48.8567380697085, 'lng': 2.351657519708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hôtel Duo',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3840,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107554201425443337224">Hôtel Duo</a>'],
#      'photo_reference': 'Aap_uEBH1YOUHSryMqo8vndMQ8EioP4zBKY_GbN-FoaaM98BOyWErdcR-_49i5XJha9nTRubutd30VmNiPkAf8UUiYaIVX2DgGkigr_QPwQW-GI1bKk6nbgXJ_AOdk7NM_7DmxuEz4mLHQtEeJbiie6MOBsSeo-ITVDEveRBajVMJEYnmLTr',
#      'width': 5760}],
#    'place_id': 'ChIJWU9CqB1u5kcR5P1F2SMoJmc',
#    'plus_code': {'compound_code': 'V953+65 Paris, France',
#     'global_code': '8FW4V953+65'},
#    'rating': 4.2,
#    'reference': 'ChIJWU9CqB1u5kcR5P1F2SMoJmc',
#    'scope': 'GOOGLE',
#    'types': ['gym',
#     'night_club',
#     'bar',
#     'lodging',
#     'point_of_interest',
#     'spa',
#     'health',
#     'establishment'],
#    'user_ratings_total': 325,
#    'vicinity': '11 Rue du Temple, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8582861, 'lng': 2.3464944},
#     'viewport': {'northeast': {'lat': 48.85954748029151,
#       'lng': 2.347782830291502},
#      'southwest': {'lat': 48.85684951970851, 'lng': 2.345084869708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Britannique Hotel - Paris Centre',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1426,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108984000175492464929">Hôtel Britannique - Paris Centre</a>'],
#      'photo_reference': 'Aap_uEAmIABThzKyq0lLw8wbG-02vLZKAEGGkxzJy76G1ckmiwJB0DEb-n13g7KYPhowbDYJJsRifa9DV6eNGl9lfxWFBx6LFixSm2sc5Bd66W5NFfIbIr98Ub2WE6ueKZK41t_vZlwSQI1FPB7bMQ-nFozonWntDCnsAbK-Z5sDNKHCPDUl',
#      'width': 1476}],
#    'place_id': 'ChIJ-4Siox9u5kcRm9vM6DcMXyU',
#    'plus_code': {'compound_code': 'V85W+8H Paris, France',
#     'global_code': '8FW4V85W+8H'},
#    'rating': 4.7,
#    'reference': 'ChIJ-4Siox9u5kcRm9vM6DcMXyU',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 739,
#    'vicinity': '20 Avenue Victoria, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8606655, 'lng': 2.3469293},
#     'viewport': {'northeast': {'lat': 48.8617746302915,
#       'lng': 2.347927730291502},
#      'southwest': {'lat': 48.8590766697085, 'lng': 2.345229769708499}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Citadines Les Halles Paris',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3000,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107376803194583900329">Fernando Costa</a>'],
#      'photo_reference': 'Aap_uEAsJ4jdC7KzjS1Oqoy5gyV8ilcDCkCwkSkqUZtldEHTImFruCsxnUIhhClW5dqK364rl0KT0o13c0lAcusT8tl4M23D9quizZ3eHBME6NRa0qRgt6G5KvWkqspXyxHM2v9tWzVNtoM-nKIZvG7QMFq6iq047kQzD1JMu_ehTQP0qbta',
#      'width': 4000}],
#    'place_id': 'ChIJQ_QDrxhu5kcRJzNxLLEOSfU',
#    'plus_code': {'compound_code': 'V86W+7Q Paris, France',
#     'global_code': '8FW4V86W+7Q'},
#    'rating': 4.1,
#    'reference': 'ChIJQ_QDrxhu5kcRJzNxLLEOSfU',
#    'scope': 'GOOGLE',
#    'types': ['city_hall',
#     'local_government_office',
#     'lodging',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 909,
#    'vicinity': '4 Rue des Innocents, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8607658, 'lng': 2.3465318},
#     'viewport': {'northeast': {'lat': 48.8620584302915,
#       'lng': 2.347692880291501},
#      'southwest': {'lat': 48.85936046970851, 'lng': 2.344994919708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Novotel Paris Les Halles',
#    'photos': [{'height': 2000,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111815616573299411056">Novotel Paris Les Halles</a>'],
#      'photo_reference': 'Aap_uEC27-Arw0BdzN2iyPZwR9AF9wV2or3WZZOQBpQSPO5aq8g2IClLFGNQNFzLJ9yMnG26k0zoX8pkkG8akXSwLzlbw8KYvAqBupv98iNE4a4GkKNI1hZBbjNQyIdZssNdN5_por3IbQeXjOTL3w9azcbJcKn04Es_qCApYccZylzW0agk',
#      'width': 3000}],
#    'place_id': 'ChIJGW2pNx9u5kcRI3oyL8NG5BQ',
#    'plus_code': {'compound_code': 'V86W+8J Paris, France',
#     'global_code': '8FW4V86W+8J'},
#    'rating': 4.4,
#    'reference': 'ChIJGW2pNx9u5kcRI3oyL8NG5BQ',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2464,
#    'vicinity': '8 Place Marguerite de Navarre, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.860352, 'lng': 2.3440948},
#     'viewport': {'northeast': {'lat': 48.86165553029149,
#       'lng': 2.345549080291502},
#      'southwest': {'lat': 48.8589575697085, 'lng': 2.342851119708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hôtel Ducs de Bourgogne',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1390,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101411638353598558320">Hôtel Ducs de Bourgogne</a>'],
#      'photo_reference': 'Aap_uED-zgAULeELI4hkgDZFViH4vwwRfHdTHHxNr7DtxICSyQVO3lcAuCJpsXvSXFSVJT1Er3VqmHQTe864brVO0JZCSVGEwfiDGh5kqIx7a0K_kr56cNPCDxvY-CO3SDH-jezbXyrV8QbsuYp7Ruzc7Jsdb-XVE3t9iuUPpOdKdQR1Re-C',
#      'width': 2048}],
#    'place_id': 'ChIJifTG5yFu5kcRdnisbwxnAx4',
#    'plus_code': {'compound_code': 'V86V+4J Paris, France',
#     'global_code': '8FW4V86V+4J'},
#    'rating': 4.5,
#    'reference': 'ChIJifTG5yFu5kcRdnisbwxnAx4',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 297,
#    'vicinity': '19 Rue du Pont Neuf, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8555091, 'lng': 2.3408736},
#     'viewport': {'northeast': {'lat': 48.8569076302915,
#       'lng': 2.342319280291502},
#      'southwest': {'lat': 48.8542096697085, 'lng': 2.339621319708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Citadines Saint-Germain-des-Prés Paris (Apart hotel Paris)',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4480,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113188832595116816387">Citadines Saint-Germain-des-Prés Paris (Apart Hotel Paris)</a>'],
#      'photo_reference': 'Aap_uEBnrUwzobj4unvq-pBkBDy7PsUtYJ5OZDIVrIZtPSQSnIQFBK3mvJw015u0-UGYqb-16eYY_8ui9JMbaGho3PxOY9ZN4j2FwnCJBC8vDfZYLsNmFnG_zc4EFywAggcdnN22YdSdeNY3EJrofFIacJVQrsawtO6WgO5fsjypaMjJMRUt',
#      'width': 6720}],
#    'place_id': 'ChIJo5pYcN9x5kcRERXdocMgqmE',
#    'plus_code': {'compound_code': 'V84R+68 Paris, France',
#     'global_code': '8FW4V84R+68'},
#    'rating': 4.3,
#    'reference': 'ChIJo5pYcN9x5kcRERXdocMgqmE',
#    'scope': 'GOOGLE',
#    'types': ['city_hall',
#     'local_government_office',
#     'lodging',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 737,
#    'vicinity': '53 ter Quai des Grands Augustins, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8524547, 'lng': 2.3472064},
#     'viewport': {'northeast': {'lat': 48.8538838802915,
#       'lng': 2.348601530291502},
#      'southwest': {'lat': 48.8511859197085, 'lng': 2.345903569708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hôtel Esmeralda',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114852001362047630790">Georgia Hentze</a>'],
#      'photo_reference': 'Aap_uEB4GtfotcDPZtlZPrQpagsbNGLhgC3vxhz4blPkrlKqGh1on_uGsad0ujJiKJsl_27wtRZVcNbdCW0VrVqPFHdSXBj3n3LQXcdPXIAZs-PvBt4_Gb8sJSBpWd51pd2BB09sIt1pRGP-8FC_fnBr_AXhtSkkrgoCa8O6bHRHGHTCme9f',
#      'width': 3024}],
#    'place_id': 'ChIJO_g_H-Fx5kcRmaabUHA3dT4',
#    'plus_code': {'compound_code': 'V82W+XV Paris, France',
#     'global_code': '8FW4V82W+XV'},
#    'rating': 4.1,
#    'reference': 'ChIJO_g_H-Fx5kcRmaabUHA3dT4',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 166,
#    'vicinity': '4 Rue Saint-Julien le Pauvre, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8530901, 'lng': 2.3447174},
#     'viewport': {'northeast': {'lat': 48.8544535802915,
#       'lng': 2.345997680291501},
#      'southwest': {'lat': 48.85175561970851, 'lng': 2.343299719708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Albe Hotel',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1152,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117571951379278191466">Albe Hotel Saint Michel</a>'],
#      'photo_reference': 'Aap_uEBVSW--220r7Eg9_ITesx_nL51FJg6k3zatMkAZkp3Rp3HxpCUvsPdz3hSAxgrZsZ03-V3KKxL5hweCf2nsPSGbW9ilaA-DrSFePaYxtzengIAbatFSF9bOEMqDpaf73bMJiRHzY7m03S3bZ0SFvZrnxBMxkkduEUSRH4nlhuTR8Gyd',
#      'width': 1600}],
#    'place_id': 'ChIJ8R5-hOBx5kcRsCOdfj8GLeY',
#    'plus_code': {'compound_code': 'V83V+6V Paris, France',
#     'global_code': '8FW4V83V+6V'},
#    'rating': 4.4,
#    'reference': 'ChIJ8R5-hOBx5kcRsCOdfj8GLeY',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 363,
#    'vicinity': '1 Rue de la Harpe, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8532403, 'lng': 2.3457375},
#     'viewport': {'northeast': {'lat': 48.85462748029149,
#       'lng': 2.347175730291502},
#      'southwest': {'lat': 48.8519295197085, 'lng': 2.344477769708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Les Rives de Notre-Dame Hotel',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116242575283063930652">Michael Scholz</a>'],
#      'photo_reference': 'Aap_uECkJ-XNTwqZysOiIyhKGihHzrZsESieYxKv_Q-6aqk0j5UWyC30kfgo_bOL6HjuBNXCFLKjIxvRDDTlN3Ha_01Ib0nk7GEP8e3_zVXR_Ni1Y7paXJfxZz2gU1kFGsbDqpNmrMJ0D_obcWKxKd_REo6LTBXB86N7Cz0_gCw819hGll88',
#      'width': 6048}],
#    'place_id': 'ChIJl7vs8-Bx5kcRfIQzq_4_XmU',
#    'plus_code': {'compound_code': 'V83W+77 Paris, France',
#     'global_code': '8FW4V83W+77'},
#    'rating': 4.6,
#    'reference': 'ChIJl7vs8-Bx5kcRfIQzq_4_XmU',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 96,
#    'vicinity': '15 Quai Saint-Michel, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.85184049999999, 'lng': 2.3448082},
#     'viewport': {'northeast': {'lat': 48.8531470802915,
#       'lng': 2.346121880291502},
#      'southwest': {'lat': 48.8504491197085, 'lng': 2.343423919708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hôtel 4 étoiles Parc Saint-Séverin Paris 5ème - Esprit de France',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2362,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107542132357877294567">Hôtel 4 étoiles Parc Saint Séverin Paris 5ème - Esprit de France</a>'],
#      'photo_reference': 'Aap_uEBeS-6YfyvTVfUld_fk--ZOmON0DWB1Nr7a3lyDfCV2GL9FdNvuLcjf6MVyoCY9zVn8jAWUMzGHkmWyjnJeuKq3DfImK6oJgmrxGfs-pIl0lyH_eRm92F-XPpLRnT_kdY4iYXQJBGGBWgECz5Yd7BroifU8Q0GFVE2Jd5NxU4ukSvRW',
#      'width': 3776}],
#    'place_id': 'ChIJ9--kuuBx5kcRojwQ1yEK2cY',
#    'plus_code': {'compound_code': 'V82V+PW Paris, France',
#     'global_code': '8FW4V82V+PW'},
#    'rating': 4.6,
#    'reference': 'ChIJ9--kuuBx5kcRojwQ1yEK2cY',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 175,
#    'vicinity': '22 Rue de la Parcheminerie, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8518743, 'lng': 2.3463436},
#     'viewport': {'northeast': {'lat': 48.8532481802915,
#       'lng': 2.347596830291502},
#      'southwest': {'lat': 48.8505502197085, 'lng': 2.344898869708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hotel Henri IV Rive Gauche',
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110759590658386679133">François TAPIEZO ART</a>'],
#      'photo_reference': 'Aap_uEA8gkGYFKjzdZH9YpjJiLO5jVb7vCh2zOmKBRZhtiCFDXCLnHbTtJC6x0tef8vm7ZJdPDFcQ8NryqaYLB7mbvmdAkAskOPXrPS8WIrluafG3tKmiyIhxEmrxJUXqb2S79Y9nx6rajQyUYVftcyO7cwRVzWRLz6UUWJYwYZOHmUyZ6Vt',
#      'width': 4032}],
#    'place_id': 'ChIJ2a4f2-Bx5kcR40Wl3uv_53Y',
#    'plus_code': {'compound_code': 'V82W+PG Paris, France',
#     'global_code': '8FW4V82W+PG'},
#    'rating': 4.5,
#    'reference': 'ChIJ2a4f2-Bx5kcR40Wl3uv_53Y',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 155,
#    'vicinity': 'Rue Saint-Jacques, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8600866, 'lng': 2.3533543},
#     'viewport': {'northeast': {'lat': 48.86148808029149,
#       'lng': 2.354740780291502},
#      'southwest': {'lat': 48.85879011970849, 'lng': 2.352042819708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hôtel Beaubourg',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3744,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115421447635584539926">Hôtel Beaubourg</a>'],
#      'photo_reference': 'Aap_uECOiDG1Z4T508mxBYdavWdpGKHLGyrvyJGcyDi4z9aMpNqx6-Su8kzQoy_M02V2xTUGHveUfns43RrVWKufEalelm7naVXLcoq80dKOCxqvsFBgiyynBUby-xz04fRVIiLnudqSy3FXwW4Vttb14OUlsZSk96acG2jtNok7STnrI_Lg',
#      'width': 5616}],
#    'place_id': 'ChIJCdHKjhxu5kcR0YtyGr7Vftc',
#    'plus_code': {'compound_code': 'V963+28 Paris, France',
#     'global_code': '8FW4V963+28'},
#    'rating': 4.2,
#    'reference': 'ChIJCdHKjhxu5kcR0YtyGr7Vftc',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 153,
#    'vicinity': '11 Rue Simon le Franc, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.859876, 'lng': 2.347049},
#     'viewport': {'northeast': {'lat': 48.8610872802915,
#       'lng': 2.348425880291502},
#      'southwest': {'lat': 48.8583893197085, 'lng': 2.345727919708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': "Hôtel Des Ducs D'Anjou",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1400,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115209143941459061727">Hotel Des Ducs D&#39;Anjou</a>'],
#      'photo_reference': 'Aap_uEDFPKKVWkVBXXpJsXlyd6unkvopJTXQtTdBPXnYM3y669YTkw0jadAvaaQ2KhUe2VmMjrZK9rJITV9vlLUe7VelvHtFsTH3J0Vhu36GpXf4duHXfPXO5-aV3DV-VrTA_s810CJmXQgtLlU3WQ8zNaKr0oKpToqlt0Vtx5JPrSRMINmW',
#      'width': 1352}],
#    'place_id': 'ChIJ9ekWGR9u5kcRsS8j5TnWeSE',
#    'plus_code': {'compound_code': 'V85W+XR Paris, France',
#     'global_code': '8FW4V85W+XR'},
#    'rating': 3.9,
#    'reference': 'ChIJ9ekWGR9u5kcRsS8j5TnWeSE',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 323,
#    'vicinity': '1 Rue Sainte-Opportune, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8515237, 'lng': 2.3486679},
#     'viewport': {'northeast': {'lat': 48.8529256302915,
#       'lng': 2.349962130291502},
#      'southwest': {'lat': 48.8502276697085, 'lng': 2.347264169708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hotel Maison Colbert Member of Meliá Collection',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3656,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102194778927204133336">Hotel Maison Colbert Member of Meliá Collection</a>'],
#      'photo_reference': 'Aap_uEAeZ2u6nR42B5U1pcn6oigDvyESkzGK1awo5btdQkw5fQGAXf_c6Qrk35jKZQZSXrLxLRenAoiel3mZO0EekU2mtwz0cPlFl_L5ItC7PrzS_FYSsT_1PlNs9CGZYZZz5_WfOrmLrWoy1wrqM3lFigcN-4Wygicq-sp68X3hIGJ5hCN8',
#      'width': 3543}],
#    'place_id': 'ChIJI3vbSOFx5kcR84E4IeL2LqI',
#    'plus_code': {'compound_code': 'V82X+JF Paris, France',
#     'global_code': '8FW4V82X+JF'},
#    'rating': 4.4,
#    'reference': 'ChIJI3vbSOFx5kcR84E4IeL2LqI',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 235,
#    'vicinity': "7 Rue de l'Hôtel Colbert, Paris"},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8499446, 'lng': 2.346247699999999},
#     'viewport': {'northeast': {'lat': 48.8513264802915,
#       'lng': 2.347622530291501},
#      'southwest': {'lat': 48.8486285197085, 'lng': 2.344924569708497}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Home Latin',
#    'photos': [{'height': 606,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105830788751825835396">Peter Sheehan</a>'],
#      'photo_reference': 'Aap_uEBhwCgAV7blROkU8iAaK9RIWmRfOG1q2dGIOx20T8XQWgFCgBEnAyy7ImYTJFoya7kxLEAtBMKdEgdIUBphnxmqWzsUIgS5-_6JhIDhPz5ZJY0TM5V30WU-5EDMdNMgihJqP1UfPD-TCrtAinCau009ET4Q6reXynX3YZnt-YTX2SQy',
#      'width': 1080}],
#    'place_id': 'ChIJMWNDIudx5kcRupjNdNDYKkw',
#    'plus_code': {'compound_code': 'R8XW+XF Paris, France',
#     'global_code': '8FW4R8XW+XF'},
#    'rating': 3.5,
#    'reference': 'ChIJMWNDIudx5kcRupjNdNDYKkw',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 333,
#    'vicinity': '15-17 Rue du Sommerard, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8514465, 'lng': 2.3495407},
#     'viewport': {'northeast': {'lat': 48.85276158029151,
#       'lng': 2.350874680291501},
#      'southwest': {'lat': 48.85006361970851, 'lng': 2.348176719708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Les Degrés de Notre Dame',
#    'photos': [{'height': 1984,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115564994803632359392">christophe etter</a>'],
#      'photo_reference': 'Aap_uEAlv4FIq1G0h9msvpvAC6Pw3PDY5_RmAcaM_ooR9aPurzr7g5X-wO14QT6VvAMXP5MeqI8woc2y6QCOGarJA048yIdbftw1OhuDx0NHvVdbSn88j8LHfiUOh0rfEswYcDdv27_By3fenGuq9VSXiPUwaT9pz0MXyFXyj-4df6HK9wnK',
#      'width': 3968}],
#    'place_id': 'ChIJMyUCVOFx5kcRcLsa7V0Y1m4',
#    'plus_code': {'compound_code': 'V82X+HR Paris, France',
#     'global_code': '8FW4V82X+HR'},
#    'rating': 3.8,
#    'reference': 'ChIJMyUCVOFx5kcRcLsa7V0Y1m4',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 78,
#    'vicinity': '10 Rue des Grands Degrés, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.85221300000001, 'lng': 2.3420703},
#     'viewport': {'northeast': {'lat': 48.8535826302915,
#       'lng': 2.343484980291502},
#      'southwest': {'lat': 48.8508846697085, 'lng': 2.340787019708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hôtel Du Lys',
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107472282758971290035">Juan pitarch roca</a>'],
#      'photo_reference': 'Aap_uEDJsljGijwiyd6fHA6ntuJCysDlZDnjVG3Amx422LRz8nD8m3QWjvYFvgs9tcY2Fba2U8i4WdaQUdd8n7JonWLluJa680odtGQZ3IGOK6wezo9EXo8j-n9t_Wt7trNhRboIB0NrNyfxII9Syw7i2sMmBoPccKvm9WZyWIZltdRsx4Kg',
#      'width': 3024}],
#    'place_id': 'ChIJrcnEaN5x5kcRjjOnEG6_HHs',
#    'plus_code': {'compound_code': 'V82R+VR Paris, France',
#     'global_code': '8FW4V82R+VR'},
#    'rating': 3.8,
#    'reference': 'ChIJrcnEaN5x5kcRjjOnEG6_HHs',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 234,
#    'vicinity': '23 Rue Serpente, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8607212, 'lng': 2.342585},
#     'viewport': {'northeast': {'lat': 48.8620849802915,
#       'lng': 2.343869380291502},
#      'southwest': {'lat': 48.8593870197085, 'lng': 2.341171419708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': "L'Empire Paris",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1123,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112201701198428774080">L&#39;Empire Paris</a>'],
#      'photo_reference': 'Aap_uEAWqaTbZGlOg60aHiwJjo4tIcIro7LoIdsHxDPteIVV3dDYdUlxxMkvQEfTwFKprovVZSefKuNlAXGaYF7QxsCfOAiwckRderTpQiWKQWJOGiM4eZuOdKQln8MLV9P91OeNPoIPBKElAdRKT6LpcSFRLaHRfZrxwoEVM5aL2C5ekJi0',
#      'width': 2000}],
#    'place_id': 'ChIJ0Wj4hCFu5kcRQ67Hb2M6b9Q',
#    'plus_code': {'compound_code': 'V86V+72 Paris, France',
#     'global_code': '8FW4V86V+72'},
#    'rating': 4.2,
#    'reference': 'ChIJ0Wj4hCFu5kcRQ67Hb2M6b9Q',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 464,
#    'vicinity': "48 Rue de l'Arbre Sec, Paris"},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.85924579999999,
#      'lng': 2.341004799999999},
#     'viewport': {'northeast': {'lat': 48.8606175802915,
#       'lng': 2.342363980291502},
#      'southwest': {'lat': 48.8579196197085, 'lng': 2.339666019708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hotel Relais Du Louvre',
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113229819060416823993">Constance Fodé</a>'],
#      'photo_reference': 'Aap_uEDsDTD3_DOH8lXnFz1K4zdPvurZrI2wciuX2WM48P2g-Ri0MxW4w5V1io7JXIroWJ16L31S1s13-NIaNgrFTIDozZIKfp1_vH2fetPUYdgpKgntBW5La-5GtuhCIBhIE7D71llisPqU1eT5Qa0t0dDmkDONdjBHp99R0PWIPbObY-tP',
#      'width': 4032}],
#    'place_id': 'ChIJb4ExGiFu5kcRx-LufqT5JSw',
#    'plus_code': {'compound_code': 'V85R+MC Paris, France',
#     'global_code': '8FW4V85R+MC'},
#    'rating': 4.6,
#    'reference': 'ChIJb4ExGiFu5kcRx-LufqT5JSw',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 138,
#    'vicinity': "19 Rue des Prêtres Saint-Germain l'Auxerrois, Paris"},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8632711, 'lng': 2.352693},
#     'viewport': {'northeast': {'lat': 48.86461498029149,
#       'lng': 2.353958580291502},
#      'southwest': {'lat': 48.8619170197085, 'lng': 2.351260619708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hôtel Georgette',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1181,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112851757923591367842">Hotel Georgette</a>'],
#      'photo_reference': 'Aap_uEAA840dB8R985EZv3GPa0KB6_Go0XPdlkiCNCTRP36PYZ5L9kZaIs56rlzEUaJrY3xnZEyu7nx3pCCTc4LDXCA9D1ls3RKEr7Etauq3a7-hVGrG4D8qPd7xfUE4ibHOG5EQdr504eeViVDHOaI9VzTTVwOOf3v95ndbwV3AoKG5iokj',
#      'width': 1772}],
#    'place_id': 'ChIJZ6OWsRtu5kcRuyOkJ6_e06E',
#    'plus_code': {'compound_code': 'V973+83 Paris, France',
#     'global_code': '8FW4V973+83'},
#    'rating': 4.5,
#    'reference': 'ChIJZ6OWsRtu5kcRuyOkJ6_e06E',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 206,
#    'vicinity': '36 Rue du Grenier-Saint-Lazare, Paris'}],
#  'status': 'OK'}

# %%
# 6a. Set parameters to search for hotels with 5000 meters.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key}

# 6b. Iterate through the hotel DataFrame.
for index, row in hotel_df.iterrows():
    # 6c. Get latitude and longitude from DataFrame
    lat = row["Lat"]
    lng = row["Lng"]
    params["location"] = f"{lat},{lng}"
    # 6d. Set up the base URL for the Google Directions API to get JSON data.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # 6e. Make request and retrieve the JSON data from the search. 
    hotels = requests.get(base_url, params=params).json()
    try:
    # 6f. Get the first hotel from the results and store the name, if a hotel isn't found skip the city.
     hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"] 
    except (IndexError):
         print("Hotel not found... skipping.")
# Out:
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '14.073,5.96'}
# Hotel not found... skipping.
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '-23.1203,-134.9692'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '25.5333,-103.25'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '22.8909,-109.9124'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '-21.2,-175.2'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '18.7369,7.3853'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '10.5669,72.642'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '45.8495,123.2973'}
# Hotel not found... skipping.
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '13.1,-59.6167'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '22.2855,114.1577'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '-10.4544,161.9205'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '-9.8,-139.0333'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '-16.4833,-151.75'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '28.4008,-97.7483'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '-8.4333,114.3333'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '14.5452,-60.8388'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '-21.2078,-159.775'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '11.0333,-63.8628'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '14.5094,-92.1933'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '25.5167,69.7667'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '14.8333,78.4'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '8.9242,-67.4293'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '14.35,121.0167'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '3.0707,172.7902'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '-3.3333,128.9167'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '29.8458,-90.1067'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '5.4444,73.3657'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '22.8833,92.7333'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '35.1668,-94.2669'}
# Hotel not found... skipping.
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '-8.7676,160.7034'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '-3.8004,102.2655'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '12.1791,125.5072'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '18.8003,110.3967'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '29.9697,40.2064'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '21.4447,-157.8378'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '5.4112,100.3354'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '7.6947,126.5503'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '-3.3667,135.4833'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '13.2167,-59.5167'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '-0.6,73.0833'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '-6.8844,112.2051'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '-8.8978,-35.1478'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '34.4166,-79.3712'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '24.7811,112.3825'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '-0.9131,122.8766'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '14.9951,-2.9517'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '41.1231,80.2644'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '-20.3167,118.5667'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '16.8634,-99.8901'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '-5.2246,145.7966'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '13.35,-15.75'}
# Hotel not found... skipping.
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '-3.945,122.4989'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '-10.1667,123.5833'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '34.6851,135.8049'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '-3.7508,103.6372'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '-9.0763,143.2092'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '1.7427,98.7792'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '39.0286,121.695'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '18.0264,-77.8487'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '38.4167,77.2406'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '12.3081,75.1063'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '33.5337,-82.1307'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '18.2,-73.75'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '20.1986,1.0114'}
# Hotel not found... skipping.
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '34.1805,117.1571'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '37.4419,-122.143'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '7.9803,49.8164'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '17.05,79.2667'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '-3.9014,-38.3911'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '17.1561,-89.0714'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '-6.9811,-34.8339'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '11.2833,-15.8333'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '9.4942,50.8122'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '-25.2986,152.8535'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '35.405,116.5814'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '35.7333,140.8333'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '37.2975,120.8256'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '-6.6024,147.8681'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '-6.7669,-43.0225'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '-2.65,10.0'}
# Hotel not found... skipping.
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '20.8947,-156.47'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '-4.7561,11.8578'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '36.4141,64.9053'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '-16.9167,145.7667'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '-3.2175,40.1191'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '38.7153,112.7575'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '41.7597,86.1469'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '24.3448,124.1572'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '30.0502,-98.0336'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '42.2683,118.9636'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '14.8961,-24.4956'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '-20.2333,164.0167'}
# Hotel not found... skipping.
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '24.4478,117.8111'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '-19.0595,-169.9187'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '19.47,72.8'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '-2.0226,147.2712'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '4.8845,-1.7554'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '-19.55,169.2667'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '7.4167,81.8167'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '11.6667,92.75'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '-20.7333,139.5'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '-8.0089,-34.8553'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '-6.1219,141.2906'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '28.017,-97.5169'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '30.15,62.6'}
# Hotel not found... skipping.
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '24.6877,46.7219'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '-7.9386,110.2506'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '10.9995,122.6711'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '21.4022,-157.7394'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '5.5577,95.3222'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '20.5169,-13.0499'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '21.2833,82.8167'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '6.8833,73.1'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '15.451,36.4'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '32.2217,-110.9265'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '-0.9492,100.3543'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '25.9873,-80.2323'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '-17.8333,-149.2667'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '35.2597,-118.9143'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '-2.5744,150.7967'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '8.3511,100.202'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '1.3292,172.9752'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '-1.5746,9.2618'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '5.3505,48.5268'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '13.2019,-16.7339'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '-4.352,152.2633'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '32.3502,-85.1999'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '-2.6741,141.3028'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '-15.8631,-38.8828'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '16.7833,94.7333'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '18.451,-78.1736'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '32.2989,69.5725'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '-17.7333,-149.15'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '15.7432,-96.4661'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '52.0779,104.0919'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '25.2088,64.6357'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '10.1725,11.4715'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '46.5586,131.4244'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '15.6167,120.9333'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '15.85,-97.0667'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '32.3513,-95.3011'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '40.2833,97.2'}
# Hotel not found... skipping.
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '13.6017,26.6876'}
# Hotel not found... skipping.
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '-8.103,156.8419'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '2.0371,45.3438'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '32.7376,-101.951'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '21.4267,39.8261'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '-20.1,146.2667'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '9.1769,105.15'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '37.3394,-121.895'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '20.5022,-10.0711'}
# Hotel not found... skipping.
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '17.65,83.2667'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '15.5667,108.4833'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '5.4033,125.4636'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '12.15,-68.2667'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '0.6,-80.0333'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '-20.7833,117.1333'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '52.1657,109.7726'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '40.7391,-114.0733'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '-10.6167,150.6667'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '33.6668,-95.5836'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '14.2,24.6667'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '7.9986,124.2928'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '39.4547,75.9797'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '-1.2675,116.8289'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '14.9709,8.8879'}
# Hotel not found... skipping.
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '2.6708,72.8944'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '9.9658,98.6348'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '-5.1989,-35.4608'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '21.3469,-158.0858'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '33.1222,46.1646'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '13.9553,7.6712'}
# Hotel not found... skipping.
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '0.8,127.4'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '12.524,-70.027'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '3.1001,98.4908'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '26.5412,-77.0636'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '-5.3582,104.9744'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '-0.3167,102.35'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '-20.0167,148.2333'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '21.4612,-71.1419'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '-22.6667,167.4833'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '22.6783,-3.9836'}
# Hotel not found... skipping.
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '-20.7377,116.8463'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '-7.6331,109.2461'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '35.1258,-117.9859'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '1.4801,103.3899'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '9.6989,10.2744'}
# Hotel not found... skipping.
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '-0.7193,8.7815'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '-2.9248,-39.9167'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '38.4953,102.1739'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '-3.1374,142.3475'}
# Hotel not found... skipping.
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '40.81,114.8794'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '-9.4333,159.95'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '53.6039,91.3903'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '18.6853,12.9164'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '32.2207,-98.2023'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '6.3711,126.1689'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '12.7667,-2.8833'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '18.217,-63.0578'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '5.8808,-10.0467'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '25.5198,90.2201'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '39.1502,-123.2078'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '24.9639,118.3794'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '35.55,133.2333'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '11.2408,-74.199'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '16.5167,-98.75'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '13.7796,124.39'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '0.5333,72.9333'}
# Hotel not found... skipping.
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '-22.2763,166.4572'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '31.8543,-110.9937'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '31.85,-112.8333'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '21.85,111.9667'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '-9.1061,124.8925'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '12.1844,18.693'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '24.0934,32.907'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '18.4167,84.05'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '22.2394,68.9678'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '-20.5667,164.2833'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '12.0564,-61.7485'}
# {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyBw6XUKfLuxJxfAAqi8ByHos18Q961z2n8', 'location': '35.5362,-100.9599'}

# %%
hotel_df.head(10)
# Out:
#               City Country  Max Temp Current Description      Lat       Lng  \
# 4          Madaoua      NE     81.39           clear sky  14.0730    5.9600
# 7          Rikitea      PF     76.44          light rain -23.1203 -134.9692
# 9        Matamoros      MX     87.55       broken clouds  25.5333 -103.2500
# 11  Cabo San Lucas      MX     76.60     overcast clouds  22.8909 -109.9124
# 14           Vaini      TO     80.76       broken clouds -21.2000 -175.2000
# 18           Arlit      NE     83.44           clear sky  18.7369    7.3853
# 26       Kavaratti      IN     83.57       moderate rain  10.5669   72.6420
# 27         Zhenlai      CN     77.70    scattered clouds  45.8495  123.2973
# 30      Bridgetown      BB     81.09    scattered clouds  13.1000  -59.6167
# 31        Victoria      HK     80.96     overcast clouds  22.2855  114.1577
#
#                           Hotel Name
# 4
# 7                    People ThankYou
# 9                       Quinta Belem
# 11            Hotel Tesoro Los Cabos
# 14               Keleti Beach Resort
# 18  Case de Passage De la Prefecture
# 26     Hotels in Lakshadweep Islands
# 27
# 30            Hilton Barbados Resort
# 31                      Mini Central

# %%
# 7. Drop the rows where there is no Hotel Name.
hotel_df.replace("", np.nan, inplace=True)
hotel_df.dropna(subset = ["Hotel Name"], inplace=True)
clean_hotel_df=hotel_df

# %%
hotel_df.head(10)
# Out:
#               City Country  Max Temp Current Description      Lat       Lng  \
# 7          Rikitea      PF     76.44          light rain -23.1203 -134.9692
# 9        Matamoros      MX     87.55       broken clouds  25.5333 -103.2500
# 11  Cabo San Lucas      MX     76.60     overcast clouds  22.8909 -109.9124
# 14           Vaini      TO     80.76       broken clouds -21.2000 -175.2000
# 18           Arlit      NE     83.44           clear sky  18.7369    7.3853
# 26       Kavaratti      IN     83.57       moderate rain  10.5669   72.6420
# 30      Bridgetown      BB     81.09    scattered clouds  13.1000  -59.6167
# 31        Victoria      HK     80.96     overcast clouds  22.2855  114.1577
# 33        Kirakira      SB     83.19          few clouds -10.4544  161.9205
# 34          Atuona      PF     78.13       broken clouds  -9.8000 -139.0333
#
#                           Hotel Name
# 7                    People ThankYou
# 9                       Quinta Belem
# 11            Hotel Tesoro Los Cabos
# 14               Keleti Beach Resort
# 18  Case de Passage De la Prefecture
# 26     Hotels in Lakshadweep Islands
# 30            Hilton Barbados Resort
# 31                      Mini Central
# 33                      SanBiz Lodge
# 34                       Villa Enata

# %%
# 8a. Create the output File (CSV)
output_data_file = "Weather_Database/hotels.csv"
# 8b. Export the City_Data into a csv
clean_hotel_df.to_csv(output_data_file, index_label="City_ID")

# %%
# 9. Using the template add city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 10a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in clean_hotel_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = clean_hotel_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map. 
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(marker_layer)

# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
